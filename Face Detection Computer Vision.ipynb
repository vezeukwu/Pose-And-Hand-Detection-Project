# %% [markdown]
# This is a computer vision project to detect the face, eyes and smile.

# %%
# iMPORTING rELEVANT lIBRARIES

import cv2

# %%
# Using the haarcascade Classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
# Creating a function that detects the face

def detect(gray, frame):
    face = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in face:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,255), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
    return frame

# %%
+ #0 - for local webcam and 1 for external webcam

while True:
    _, frame = capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow("Video", canvas)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
capture.release()
cv2.destroyAllWindows()  



#else: 
#continue
  #  if frame is None or not _:
   #     print("Error: Failed to capture frame from video source")
    #break

     
#if canvas is not None:
 #       print("Error: Empty frame, skipping iteration")
  #  break

# %%
capture = cv2.VideoCapture(r"C:\Users\Admin\Desktop\Media1.mp4") #0 - for local webcam and 1 for external webcam

#capture = cv2.VideoCapture(r"C:\Users\Admin\Pictures\MAT.jpg")

while True:
    _, frame = capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow("Video", canvas)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[41], line 7
#       5 while True:
#       6     _, frame = capture.read()
# ----> 7     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       8     canvas = detect(gray, frame)
#       9     cv2.imshow("Video", canvas)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ## Eye Detection

# %%
# Using the haarcascade Classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# %%
# Creating a function that detects the face and the eyes rectangle

def detect(gray, frame):
    face = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in face:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,255), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]

        # Eye detection
        eyes = eye_cascade.detectMultiScale(gray, 1.1, 3)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(frame, (ex,ey), (ex+ew, ey+eh), (100, 255, 200), 1)
        
    return frame

# %%
#capture = cv2.VideoCapture(0) #0 - for local webcam and 1 for external webcam

capture = cv2.VideoCapture(r"C:\Users\Admin\Pictures\MAT.jpg")

while True:
    _, frame = capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow("Video", canvas)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 7
#       5 while True:
#       6     _, frame = capture.read()
# ----> 7     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       8     canvas = detect(gray, frame)
#       9     cv2.imshow("Video", canvas)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ###  Smile Detection

# %%
# Using the haarcascade Classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")
smile_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_smile.xml")

# %%
# Creating a function that detects the face, the eyes and the smile rectangles

def detect(gray, frame):
    face = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in face:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,255), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]

        # Eye detection
        eyes = eye_cascade.detectMultiScale(gray, 1.1, 3)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(frame, (ex,ey), (ex+ew, ey+eh), (100, 255, 200), 1)

        # Smile detection
        smiles = smile_cascade.detectMultiScale(gray, 1.7, 22)
        for (sx, sy, sw, sh) in smiles:
            cv2.rectangle(frame, (sx,sy), (sx+sw, sy+sh), (100, 255, 200), 1)
    
    return frame

# %%
capture = cv2.VideoCapture(0) #0 - for local webcam and 1 for external webcam

#capture = cv2.VideoCapture(r"C:\Users\Admin\Pictures\MAT.jpg")

while True:
    _, frame = capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow("Video", canvas)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
capture.release()
cv2.destroyAllWindows()
